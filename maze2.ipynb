# %%
import numpy as np
import gym
from IPython import display
import matplotlib.pyplot as plt
from utils import plot_policy, plot_values, test_agent
from envs import Maze
# %matplotlib inline

# %%
def random_policy(env):
    return np.array([0.25]*4)
env = Maze()
state = env.reset()

# %%
action_probability = random_policy(env)
object = ('Up','Right','Down','Left')
y_pos = np.arange(len(object))

# %%
plt.bar(y_pos, action_probability, alpha=0.5)
plt.xticks(y_pos, object)
plt.ylabel('P(a|s)')
plt.title('Random Policy')
plt.tight_layout()
plt.show()

# %%
env.reset()
done = False
img = plt.imshow(env.render(mode='rgb_array'))
while not done:
    action = np.random.choice(range(4),1,p=action_probability)
    _,_,done,_ = env.step(action)
    img.set_data(env.render(mode='rgb_array'))
    plt.axis('off')
    display.display(plt.gcf())
    display.clear_output(wait=True)
env.close()

# %%
env = Maze()
frame = env.render(mode='rgb_array')
plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(frame)

# %%
policy_probs = np.full((5,5,4), 0.25)
def policy(state):
    return policy_probs[state]

action_probability = policy((0,0))
for action, prob in zip(range(4), action_probability):
    print(f"Probability of taking action {action} = {prob}")
# Out:
# Probability of taking action 0 = 0.25
# Probability of taking action 1 = 0.25
# Probability of taking action 2 = 0.25
# Probability of taking action 3 = 0.25

# %%
plot_policy(policy_probs, frame)

# %%
plot_values(np.zeros((5,5)),frame)
